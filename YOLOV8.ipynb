# %% [markdown]
# <a href="https://colab.research.google.com/github/Jasminetsmr/Deep-Learning/blob/main/YOLOV8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.55 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.7/112.6 GB disk)

# %%
# Train YOLOv8n on COCO8 for 50 epochs
# !yolo train model=yolov8n.pt data=/content/drive/MyDrive/yolov8augmented/data.yaml epochs=200 imgsz=640
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 121MB/s]
# Ultralytics 8.3.55 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=/content/runs/detect/train/weights/best.pt source='/content/IMG_1898_JPG_jpg.rf.a67ef2d7785a6a2cd9e703830ce4079e.jpg'
# Out:
# Ultralytics 8.3.55 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/IMG_1898_JPG_jpg.rf.a67ef2d7785a6a2cd9e703830ce4079e.jpg: 640x640 68 cotyledon_appears, 3 germinated_seeds, 13 not_germinateds, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 675.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
